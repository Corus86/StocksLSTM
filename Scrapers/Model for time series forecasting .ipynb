# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

# %%
df = pd.read_csv('Apple merged.csv')

# %%
# Out:
#      Unnamed: 0  Unnamed: 0.1        date        high         low        open  \
# 0             0             3  1503581400   40.185001   39.637501   40.107498
# 1             1             4  1503667800   40.139999   39.817501   39.912498
# 2             2            10  1504618200   41.062500   40.139999   40.937500
# 3             3            13  1504877400   40.287498   39.632500   40.215000
# 4             4            15  1505223000   40.990002   39.692501   40.652500
# ..          ...           ...         ...         ...         ...         ...
# 299         299          1052  1635168600  149.369995  147.619995  148.679993
# 300         300          1053  1635255000  150.839996  149.009995  149.330002
# 301         301          1054  1635341400  149.729996  148.490005  149.360001
# 302         302          1055  1635427800  153.169998  149.720001  149.820007
# 303         303          1056  1635514200  149.940002  146.410004  147.220001
#
# ...
